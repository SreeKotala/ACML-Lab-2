# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, losses
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split

import PIL
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data from a numpy file 
data = np.load("cifar-10.npz")
filenames = ['x_train', 'y_train', 'x_test', 'y_test']
nps = []

for filename in filenames:
    nps.append(data[filename])
    
train_images, train_labels, test_images, test_labels = nps

# %%
# Prepare the transformations
def to_grayscale(image):
    image = tf.image.rgb_to_grayscale(image)
    return image

datagen_norm = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255,
)

datagen_gray = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=to_grayscale
)

# %%
# Combine the data -> done to overcome the silly 50k/10k split
X = np.concatenate((train_images, test_images))
y = np.concatenate((train_labels, test_labels))

# Normalize the data
trans_norm = datagen_norm.flow(X, batch_size=len(X))
X = trans_norm.next()

# Split the data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_train_gray = X_train.copy()

# %%
# TAKES A MINUTE ON MY COMPUTER

# Apply the transformation
trans_train_gray = datagen_gray.flow(X_train_gray, batch_size=len(X_train),shuffle=False)
trans_test_gray = datagen_gray.flow(X_test, batch_size=len(X_test),shuffle=False)

# Store the transformed GRAY images
X_train_gray = trans_train_gray.next()
X_test_gray = trans_test_gray.next()

# %%
# Plot the images just to be sure the transformations worked

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    
    # set the cmap to gray otherwise it uses the default matlab format of yellows+blues
    plt.imshow(X_train_gray[i])
plt.show()

# %%
# Build the model
class Autoencoder(Model):
    
    def __init__(self):
        super(Autoencoder, self).__init__()
        
        self.encoder = tf.keras.Sequential([
            layers.Conv2D(8, (3, 3), activation='relu', padding="same", strides=1, input_shape=(32, 32, 3)),
            layers.MaxPooling2D((2, 2)),
            layers.Conv2D(12, (3, 3), activation='relu', padding="same", strides=1),
            layers.MaxPooling2D((2, 2)),
            layers.Conv2D(16, (3, 3), activation='relu', padding="same", strides=1)
        ])
        
        self.decoder = tf.keras.Sequential([
            layers.UpSampling2D(size=(2,2)),
            layers.Conv2D(12, (3, 3), activation='relu', padding="same", strides=1),
            layers.UpSampling2D(size=(2,2)),
            layers.Conv2D(3, (3, 3), activation='relu', padding="same", strides=1)
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Compile the model
autoencoder = Autoencoder()
autoencoder.compile(optimizer='adam', 
                    loss=losses.MeanSquaredError(),
                    metrics=["accuracy"])

# %%
# Train the model
history = autoencoder.fit(X_train_gray, X_train, epochs=20, batch_size=64, 
                    validation_split = (0.1/0.9),
                    validation_data=(X_test, X_test))
# Out:
# Epoch 1/20
# 750/750 [==============================] - 34s 45ms/step - loss: 0.0090 - accuracy: 0.4904 - val_loss: 0.0134 - val_accuracy: 0.5170
# Epoch 2/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0089 - accuracy: 0.4951 - val_loss: 0.0130 - val_accuracy: 0.4960
# Epoch 3/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0089 - accuracy: 0.4942 - val_loss: 0.0129 - val_accuracy: 0.5213
# Epoch 4/20
# 750/750 [==============================] - 34s 46ms/step - loss: 0.0088 - accuracy: 0.4950 - val_loss: 0.0142 - val_accuracy: 0.5130
# Epoch 5/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0088 - accuracy: 0.4957 - val_loss: 0.0135 - val_accuracy: 0.5373
# Epoch 6/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0088 - accuracy: 0.4957 - val_loss: 0.0135 - val_accuracy: 0.5272
# Epoch 7/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0088 - accuracy: 0.4960 - val_loss: 0.0131 - val_accuracy: 0.4852
# Epoch 8/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0088 - accuracy: 0.4963 - val_loss: 0.0129 - val_accuracy: 0.5153
# Epoch 9/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0088 - accuracy: 0.4966 - val_loss: 0.0124 - val_accuracy: 0.5433
# Epoch 10/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4979 - val_loss: 0.0141 - val_accuracy: 0.5299
# Epoch 11/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4980 - val_loss: 0.0126 - val_accuracy: 0.5161
# Epoch 12/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4974 - val_loss: 0.0131 - val_accuracy: 0.5509
# Epoch 13/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4969 - val_loss: 0.0135 - val_accuracy: 0.4871
# Epoch 14/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4956 - val_loss: 0.0126 - val_accuracy: 0.5180
# Epoch 15/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4982 - val_loss: 0.0122 - val_accuracy: 0.5057
# Epoch 16/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0086 - accuracy: 0.4978 - val_loss: 0.0123 - val_accuracy: 0.5314
# Epoch 17/20
# 750/750 [==============================] - 32s 42ms/step - loss: 0.0087 - accuracy: 0.4974 - val_loss: 0.0122 - val_accuracy: 0.5371
# Epoch 18/20
# 750/750 [==============================] - 32s 43ms/step - loss: 0.0086 - accuracy: 0.4965 - val_loss: 0.0123 - val_accuracy: 0.5362
# Epoch 19/20
# 750/750 [==============================] - 32s 43ms/step - loss: 0.0086 - accuracy: 0.4971 - val_loss: 0.0127 - val_accuracy: 0.4815
# Epoch 20/20
# 750/750 [==============================] - 33s 44ms/step - loss: 0.0086 - accuracy: 0.4976 - val_loss: 0.0120 - val_accuracy: 0.5232

# %%
# Plot the valuation metrics
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# Make the predictions
predictions = autoencoder.predict(X_test_gray[:n])
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
# Check the predictions 
n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test_gray[i])
    plt.title("original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

  # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(predictions[i])
    plt.title("reconstructed")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
